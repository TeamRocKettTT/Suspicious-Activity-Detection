# %%
import pickle
model = pickle.load(open('model/cnn_history.pckl','rb'))

# %%
with open('model/cnn_history.pckl', 'rb') as f:
    # Load the data from the pickle file
    data = pickle.load(f)

# %%
print(data)
# Out:
# {'val_loss': [1.8051985502243042, 1.8419389724731445, 1.9029146432876587, 1.9602830410003662, 1.9780247211456299, 2.004534959793091, 2.0183804035186768, 2.0376222133636475, 2.071591854095459, 2.097609758377075, 2.129429817199707, 2.2978549003601074, 1.9206020832061768, 2.4021430015563965, 2.2667088508605957], 'val_accuracy': [0.125, 0.25, 0.125, 0.0, 0.0, 0.0, 0.0, 0.125, 0.125, 0.0, 0.0, 0.125, 0.25, 0.0, 0.0], 'loss': [1.798836588859558, 1.7337751388549805, 1.6955314874649048, 1.653656005859375, 1.6077593564987183, 1.5388524532318115, 1.460573434829712, 1.497714638710022, 1.3467799425125122, 1.2698265314102173, 1.2940605878829956, 1.1033604145050049, 1.270898699760437, 1.2563732862472534, 1.2344636917114258], 'accuracy': [0.2857143, 0.35714287, 0.25, 0.4642857, 0.39285713, 0.42857143, 0.5, 0.42857143, 0.53571427, 0.60714287, 0.53571427, 0.71428573, 0.53571427, 0.5, 0.64285713]}

# %%
import numpy as np

# Load X.npy file
X = np.load('model/X.txt.npy')

# Load Y.npy file
Y = np.load('model/Y.txt.npy')

# Print or inspect the contents
print("X shape:", X.shape)
print("Y shape:", Y.shape)

# Depending on the size and structure of the arrays, you may choose to print them entirely or inspect specific parts.
# For example, you can print the first few elements of X and Y:
print("First few elements of X:", X[:5])
print("First few elements of Y:", Y[:5])
# Out:
# X shape: (67550, 1, 32, 32, 3)
# Y shape: (67550,)
# First few elements of X: [[[[[0.3019608  0.29803923 0.30588236]
#     [0.33333334 0.3137255  0.31764707]
#     [0.33333334 0.33333334 0.33333334]
#     ...
#     [0.33333334 0.30588236 0.42352942]
#     [0.35686275 0.32941177 0.41568628]
#     [0.60784316 0.62352943 0.6431373 ]]
#
#    [[0.3137255  0.30980393 0.31764707]
#     [0.34509805 0.3254902  0.32941177]
#     [0.31764707 0.31764707 0.31764707]
#     ...
#     [0.4        0.3882353  0.45490196]
#     [0.29411766 0.25882354 0.41960785]
#     [0.59607846 0.627451   0.6627451 ]]
#
#    [[0.34117648 0.29803923 0.33333334]
#     [0.32941177 0.3137255  0.3254902 ]
#     [0.32156864 0.32156864 0.32156864]
#     ...
#     [0.3529412  0.34509805 0.4       ]
#     [0.32156864 0.34117648 0.4117647 ]
#     [0.44313726 0.49803922 0.44705883]]
#
#    ...
#
#    [[0.20392157 0.1254902  0.18431373]
#     [0.1254902  0.07843138 0.1254902 ]
#     [0.08627451 0.08627451 0.11372549]
#     ...
# ...

# %%
 save_best_only = True
